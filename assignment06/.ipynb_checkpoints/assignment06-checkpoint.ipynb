# %% [markdown]
# ## This script demonstrates Computation of Image Features using Convolution { - }
# ### Name : Ji-Su Lee  {-}
# ### Student ID : 20141718  {-}
# ### github link : https://github.com/Jisu-Lee/HII {-}

# %% [markdown]
# ### import packages for plotting graphs and manipulating data {-}

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### setting variables {-}

# %%
num     = 201
std     = 20
a       = 2 
b       = 10

# x  : x-coordinate data
# y1 : (noisy) y-coordinate data
# y2 : (clean) y-coordinate data 
# y = f(x) = a * x + b
n       = np.random.rand(num)
nn      = n - np.mean(n)
x       = np.linspace(-100,100,num)
y1      = a * x + nn * std + b 
y2      = a * x + b

# %% [markdown]
# ### show noisy data and clean data {-}
# #### blue dot : noisy data {-}
# #### black line : clean data{-}

# %%
plt.plot(x, y1, 'b.', x, y2, 'k--')
plt.show()

# %% [markdown]
# ### calculate slope of the line of best fit {-}

# %%
xm = np.mean(x)
ym = np.mean(y)
xt = [t - xm for t in x]
yt = [u - ym for u in y1]
af = np.sum(np.multiply(xt, yt)) \
        /float(np.sum(np.square([t - xm for t in x])))

# %% [markdown]
# ### calculate y-intercept {-}

# %%
bf = ym - af*xm

# %% [markdown]
# ### let me show the line of best fit {-}
# #### blue dot : noisy data {-}
# #### red line : best fit {-}

# %%
y3 = af * x + bf
plt.plot(x, y1, 'b.', x, y3, 'r--')
plt.show()

# %% [markdown]
# ### this is the funtion of line of best fit {-}

# %%
print(str(af) + "x + " + str(bf))
# Out:
# 1.9967109533073408x + 5.0
